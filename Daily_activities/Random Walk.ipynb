# %% [markdown]
# # Brownian Motion
#
# The observation of Brownian Motion by a botanist led Einstein to conclude that this effect is exerimental evidence that matter is made up of discrete particles, supporting the existence of atoms and molecules.
#
# Observe the particles undergoing Brownian Motion in the video below. Choose one particle, and try to track its path over time. Then choose another and do the same. This seemingly random motion of particles is called Brownian Motion, and we can model this with a random walk.
#
# $$ dX_{t}=\mu dt+\sigma dW_{t}$$
# Here $W_{t}$ is the Wiener process, $ \mu $ is the drift and $\sigma$ is the diffusion coefficient.
# $$ \Delta X=\mu\Delta t+\sigma\Delta W $$
# Diffusion parameters: $ \mu $ , $ \sigma $ , $ \Delta t $
# $$ \Delta x=\mathit{\mathcal{N}}(\mu\Delta t,\sigma^{2}\Delta t) $$
# ### To Do:
#     1) Model a random walk
#
#
# You do not have to write your own function to sample from a Gaussian distribution. A normal (Gaussian) distribution called `normal` can be called from the `numpy.random package`.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("cDcprgWiQEY")

# %%
# place imports here
# %matplotlib inline
from pylab import plot, hist
from random import random
from numpy.random import normal
from math import sqrt

# %%
N = 1000
N_particles = 1
for n in range(N_particles):
    X = []
    Y = []
    x = 0.
    y = 0.
    X.append(x)
    Y.append(y)
    for i in range(N):
        x += 2*random()-1
        y += 2*random()-1
        X.append(x)
        Y.append(y)
    plot(X,Y)

# %%
N = 100
N_particles = 20

for x in range(-2, 2):
    for y in range(-2,2):
        X = []
        Y = []

        X.append(x)
        Y.append(y)
        for i in range(N):
            x += 2*random()-1
            y += 2*random()-1
            X.append(x)
            Y.append(y)
        plot(X,Y)

# %%
# Brownian Motion
mu = 0.2;
sigma = 2.0
Dt = 0.1
stdev = sqrt(Dt)*sigma


N = 1000
N_particles = 10
D = 0.1
for n in range(N_particles):
    X = []
    Y = []
    x = 0.
    y = 0.
    X.append(x)
    Y.append(y)
    for i in range(N):
        a = normal(0, .6)
        b = normal(0, .6)
        #print(a)
        #b = random()
        x += a      
        y += b
        X.append(x)
        Y.append(y)
    plot(X,Y)
    plot(0,0,'ko')

# %%
X = normal(0,1,500)
#print(X)

# %%
plot(X)

# %%
hist(X)
# Out:
# (array([   9.,   21.,   48.,   99.,  127.,   97.,   67.,   26.,    5.,    1.]),
#  array([-2.83377772, -2.21771094, -1.60164416, -0.98557738, -0.3695106 ,
#          0.24655617,  0.86262295,  1.47868973,  2.09475651,  2.71082329,
#          3.32689007]),
#  <a list of 10 Patch objects>)
